# %%
import cv2
import matplotlib.pyplot as plt

# %%
gambar = cv2.imread('./test_images/test1.jpg')
gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)
gambar[500][600]
# Out:
# array([200, 184, 168], dtype=uint8)

# %%
plt.imshow(gambar)

# %%
gray = cv2.cvtColor(gambar, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')

# %%
gray[0][0]
# Out:
# 237

# %%
gambar[0][0]
# Out:
# array([245, 235, 226], dtype=uint8)

# %%
gambar_Red = gambar[:,:,0]

# %%
plt.imshow(gambar_Red)

# %%
gambar
# Out:
# array([[[245, 235, 226],
#         [242, 238, 235],
#         [193, 206, 215],
#         ...,
#         [ 11,  36,  58],
#         [ 16,  38,  59],
#         [ 28,  49,  70]],
#
#        [[242, 238, 235],
#         [188, 193, 196],
#         [139, 158, 173],
#         ...,
#         [ 74, 108, 135],
#         [ 47,  77, 105],
#         [  4,  34,  60]],
#
#        [[190, 203, 212],
#         [135, 157, 171],
#         [118, 153, 181],
#         ...,
#         [ 96, 144, 182],
#         [ 91, 136, 175],
#         [ 52,  97, 136]],
#
#        ...,
#
#        [[142, 131, 129],
#         [132, 121, 117],
#         [114, 100,  97],
#         ...,
#         [ 99,  80,  74],
#         [ 99,  80,  74],
#         [113,  94,  88]],
#
#        [[164, 154, 152],
#         [133, 122, 118],
#         [120, 106, 103],
#         ...,
#         [107,  88,  82],
#         [109,  90,  84],
#         [111,  92,  86]],
#
#        [[189, 179, 177],
#         [135, 126, 121],
#         [130, 116, 113],
# ...

# %%
gambar[:,:,1]
# Out:
# array([[235, 238, 206, ...,  36,  38,  49],
#        [238, 193, 158, ..., 108,  77,  34],
#        [203, 157, 153, ..., 144, 136,  97],
#        ...,
#        [131, 121, 100, ...,  80,  80,  94],
#        [154, 122, 106, ...,  88,  90,  92],
#        [179, 126, 116, ...,  78,  76,  54]], dtype=uint8)

# %%
plt.imshow(gambar)

# %%
matriks[1]
# Out:
# [4, 5, 6]

# %%
gambarHSV = cv2.cvtColor(gambar, cv2.COLOR_RGB2HSV)
plt.imshow(gambarHSV)

# %%
gambarHSV
# Out:
# array([[[ 14,  20, 245],
#         [ 13,   7, 242],
#         [102,  26, 215],
#         ...,
#         [104, 207,  58],
#         [105, 186,  59],
#         [105, 153,  70]],
#
#        [[ 13,   7, 242],
#         [101,  10, 196],
#         [103,  50, 173],
#         ...,
#         [103, 115, 135],
#         [105, 141, 105],
#         [104, 238,  60]],
#
#        [[102,  26, 212],
#         [102,  54, 171],
#         [103,  89, 181],
#         ...,
#         [103, 120, 182],
#         [104, 122, 175],
#         [104, 158, 136]],
#
#        ...,
#
#        [[  5,  23, 142],
#         [  8,  29, 132],
#         [  5,  38, 114],
#         ...,
#         [  7,  64,  99],
#         [  7,  64,  99],
#         [  7,  56, 113]],
#
#        [[  5,  19, 164],
#         [  8,  29, 133],
#         [  5,  36, 120],
#         ...,
#         [  7,  60, 107],
#         [  7,  58, 109],
#         [  7,  57, 111]],
#
#        [[  5,  16, 189],
#         [ 11,  26, 135],
#         [  5,  33, 130],
# ...
